# %% [markdown]
# realizaremos un emoji de un avion:
#
# - _____
# - \ ...\
# - .\ ...\
# - ._\ ___\ ___________________________________________
# - /  ____ ...o...o..._o____o___o___o__ o...o....o..o...o...o...o....\ _
# - \ \ ____\ ........\ _____\ _________\ ..............................................\
# - .\ _____________________________________________________/

# %% [markdown]
# (()(()
# (=*_*)/")
# c(,,)(,,)
